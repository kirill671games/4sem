# %%
import numpy as np
import matplotlib.pyplot as plt

mass1=np.random.uniform(0.0, 1.0, 10)
massy1=np.random.uniform(0.0, 1.0, 10)
mass2=np.random.normal(0.0, 1.0, 1000)
massy2=np.random.normal(0.0, 1.0, 1000)
mass3=np.random.lognormal(0.0, 1.0, 1000)
massy3=np.random.lognormal(0.0, 1.0, 1000)

print(mass1, '\n')
print(mass2, '\n')
print(mass3)

x, y = mass2, massy2
labels = ['A', 'B', 'C', 'D']

plt.scatter(x, y)
for x_coord, y_coord, label in zip(x, y, labels):
    plt.text(x_coord, y_coord, label)

plt.show()

x, y = mass3, massy3
labels = ['A', 'B', 'C', 'D']

plt.scatter(x, y)
for x_coord, y_coord, label in zip(x, y, labels):
    plt.text(x_coord, y_coord, label)

plt.show()
# Out:
# [0.59551788 0.39790665 0.80460751 0.81960995 0.95103393 0.60749531
#  0.92291923 0.45429752 0.66119226 0.90696336]
#
# [-3.85108976e-01  3.44199802e-01 -1.78809610e+00  9.35256881e-01
#   1.43585928e+00 -7.03028735e-02  2.77370536e+00 -1.31752118e+00
#  -1.38305529e+00 -4.78397617e-01  1.41647738e+00 -3.31976275e-01
#   1.08163092e+00 -2.01189648e+00 -1.12750802e+00  5.83994055e-01
#   2.11836409e-01  2.15378541e+00  1.59469391e+00 -2.67572640e+00
#  -2.27902370e+00  1.06374621e-01  8.58640167e-01  3.17088370e-01
#   1.09428333e-01  2.22455007e-01  2.37485546e-01 -2.65065482e-01
#  -8.59183284e-01  2.09459580e-01  3.72175832e-01 -2.30401547e+00
#   1.81651466e-01  3.52755330e-01  6.62138811e-01 -8.20150464e-01
#   4.78341803e-01 -2.35076638e-01 -1.25007311e-01  9.58219137e-02
#   9.37700321e-01 -6.27143470e-02 -9.38115263e-01 -4.12078680e-01
#   4.43148288e-01 -1.63317540e+00  1.21586442e+00 -2.43138676e-01
#  -5.40041383e-01  4.50351472e-01 -1.09152477e+00 -1.02484979e-01
# ...
